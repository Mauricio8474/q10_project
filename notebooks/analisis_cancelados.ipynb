# %% [markdown]
# # ETL

# %%
import pandas as pd

df = pd.read_csv("../data/raw/cancelados.csv")
df_est = pd.read_csv("../data/raw/estudiantes.csv")

TOTAL_EST = df_est['Numero_identificacion'].nunique()
TOTAL_CANCEL = len(df)
TASA_GLOBAL = round(TOTAL_CANCEL / TOTAL_EST * 100, 1)

print(f"Estudiantes únicos: {TOTAL_EST:,}")
print(f"Cancelaciones totales: {TOTAL_CANCEL:,}")
print(f"Tasa global de cancelación: {TASA_GLOBAL}%")

df.head(10)
# Out:
# Estudiantes únicos: 881
# Cancelaciones totales: 81
# Tasa global de cancelación: 9.2%
#    Codigo_estudiante Abreviatura_tipo_identificacion  Numero_identificacion  \
# 0       115285695073                            C.C.             1082876320
# 1       115840698175                            T.I.             1082924478
# 2       111644212306                            C.C.             1082837869
# 3       118151195269                            C.C.             1193156037
# 4       111568640266                            C.C.             1082982402
# 5       118258102369                             PPT                6934964
# 6       110163026970                            C.C.             1082874988
# 7       113713180844                            C.C.             1082958078
# 8       115124707514                            C.C.             1082910597
# 9       119563186530                            T.I.             1082937352
#
#         Nombre_completo_estudiante  Codigo_matricula     Codigo_programa  \
# 0    FERNEY STICK MARULANDA MONTES              1329  Tecnolog-Logis-Bas
# 1      Gabriel Jarok Herrera Creus              1167  Tecnolog-Logis-Bas
# 2       Bechkam Jousep Luna Suarez              1003  Tecnolog-Logis-Bas
# 3     Sibelly Elena Arango Mendoza              1006  Tecnolog-Logis-Bas
# 4        Julieth Paola Silva Silva              1290  Tecnolog-Logis-Bas
# 5            MARIA ANGEL REY PEREZ              1172    Tecnolog-Mkt-Bas
# 6  RAFAEL DAVID DE ALBA FERRADANES               973    Tecnolog-Mkt-Bas
# 7        LEIDI JOANA RICO BUSTILLO               733  Tecnolog-Turis-Bur
# 8    CAMILO ANDRES DUARTE ANGARITA               662  Tecnolog-Turis-Bur
# 9          MARIA JOSE RICO CHURRIO               602  Tecnolog-Turis-Bur
#
#                                      Nombre_programa  \
# 0  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...
# 1  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...
# 2  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...
# 3  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...
# 4  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...
# 5         BASTIDAS - TECNOLOGÍA EN MARKETING DIGITAL
# 6         BASTIDAS - TECNOLOGÍA EN MARKETING DIGITAL
# 7  BURITACA - TECNOLOGÍA EN GESTIÓN DEL TURISMO C...
# 8  BURITACA - TECNOLOGÍA EN GESTIÓN DEL TURISMO C...
# 9  BURITACA - TECNOLOGÍA EN GESTIÓN DEL TURISMO C...
#
#    Consecutivo_sede_jornada   Nombre_sede_jornada  Consecutivo_periodo  ...  \
# 0                         1  Principal - Completa                    6  ...
# 1                         1  Principal - Completa                    6  ...
# 2                         1  Principal - Completa                    6  ...
# 3                         1  Principal - Completa                    6  ...
# 4                         1  Principal - Completa                    6  ...
# 5                         1  Principal - Completa                    6  ...
# 6                         1  Principal - Completa                    6  ...
# 7                         1  Principal - Completa                    6  ...
# 8                         1  Principal - Completa                    6  ...
# 9                         1  Principal - Completa                    6  ...
#
#   Consecutivo_tipo_cancelacion  Descripcion_tipo_cancelacion  \
# 0                            1                     Cancelado
# 1                            3                      Aplazado
# 2                            1                     Cancelado
# 3                            1                     Cancelado
# 4                            1                     Cancelado
# 5                            1                     Cancelado
# 6                            1                     Cancelado
# 7                            1                     Cancelado
# 8                            2                      Desertor
# 9                            2                      Desertor
#
#   Consecutivo_causa_cancelacion  \
# 0                             6
# 1                             9
# 2                             6
# 3                             6
# 4                             6
# 5                             6
# 6                             6
# 7                             9
# 8                            11
# 9                            11
#
#                             Nombre_causa_cancelacion  \
# 0                                         Voluntario
# 1                                       Aplazamiento
# 2                                         Voluntario
# 3                                         Voluntario
# 4                                         Voluntario
# 5                                         Voluntario
# 6                                         Voluntario
# 7                                       Aplazamiento
# 8  Pérdida de la condición de estudiante por inas...
# 9  Pérdida de la condición de estudiante por inas...
#
#                              Observacion_cancelacion Codigo_administrativo  \
# 0  El estudiante se realiza retiro voluntario de ...          330785652662
# 1  El estudiante aplaza su semestre por motivos p...          330785652662
# 2  El estudiante decide retirarse por dificultade...          330785652662
# 3  La estudiante se retira del programa  por moti...          330785652662
# 4  La estudiante se retira del programa por temas...          330785652662
# 5  La estudiante decide retirarse ya que inició e...          330785652662
# 6  El estudiante decide retirarse por motivos de ...          330785652662
# 7   La estudiante realiza aplazamiento del semestre.          330785652662
# 8    Se cancela la matricula según circular 011-2026          330785652662
# 9    Se cancela la matricula según circular 011-2026          330785652662
#
#        Nombre_administrativo     Fecha_nacimiento Edad  Genero
# 0  MARTA LUCIA SITU CASTILLO  2006-03-30T00:00:00   20       M
# 1  MARTA LUCIA SITU CASTILLO  2008-04-19T00:00:00   18       M
# 2  MARTA LUCIA SITU CASTILLO  2003-01-31T00:00:00   23       M
# 3  MARTA LUCIA SITU CASTILLO  2000-11-01T00:00:00   25       F
# 4  MARTA LUCIA SITU CASTILLO  1994-01-06T00:00:00   32       F
# 5  MARTA LUCIA SITU CASTILLO  2007-04-11T00:00:00   19       M
# 6  MARTA LUCIA SITU CASTILLO  2006-01-08T00:00:00   20       M
# 7  MARTA LUCIA SITU CASTILLO  1992-09-29T00:00:00   33       F
# 8  MARTA LUCIA SITU CASTILLO  2007-06-25T00:00:00   18       M
# 9  MARTA LUCIA SITU CASTILLO  2009-07-30T00:00:00   16       F
#
# [10 rows x 24 columns]

# %%
print(df.columns)
df.drop(columns=['Codigo_estudiante', 'Abreviatura_tipo_identificacion',
       'Numero_identificacion', 'Nombre_completo_estudiante',
       'Codigo_matricula', 'Codigo_programa',
       'Consecutivo_sede_jornada', 'Nombre_sede_jornada',
       'Consecutivo_periodo','Codigo_nivel',
       'Consecutivo_tipo_cancelacion',
       'Descripcion_tipo_cancelacion', 'Consecutivo_causa_cancelacion',
       'Codigo_administrativo', 'Nombre_administrativo', 'Fecha_nacimiento'], 
       inplace=True)
df.head(5)
# Out:
# Index(['Codigo_estudiante', 'Abreviatura_tipo_identificacion',
#        'Numero_identificacion', 'Nombre_completo_estudiante',
#        'Codigo_matricula', 'Codigo_programa', 'Nombre_programa',
#        'Consecutivo_sede_jornada', 'Nombre_sede_jornada',
#        'Consecutivo_periodo', 'Nombre_periodo', 'Codigo_nivel', 'Nombre_nivel',
#        'Fecha_cancelacion', 'Consecutivo_tipo_cancelacion',
#        'Descripcion_tipo_cancelacion', 'Consecutivo_causa_cancelacion',
#        'Nombre_causa_cancelacion', 'Observacion_cancelacion',
#        'Codigo_administrativo', 'Nombre_administrativo', 'Fecha_nacimiento',
#        'Edad', 'Genero'],
#       dtype='object')
#                                      Nombre_programa Nombre_periodo  \
# 0  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...         2026-1
# 1  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...         2026-1
# 2  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...         2026-1
# 3  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...         2026-1
# 4  BASTIDAS - TECNOLOGÍA EN GESTIÓN DE OPERACIONE...         2026-1
#
#   Nombre_nivel    Fecha_cancelacion Nombre_causa_cancelacion  \
# 0  Semestre 01  2026-03-09T00:00:00               Voluntario
# 1  Semestre 01  2026-03-13T00:00:00             Aplazamiento
# 2  Semestre 01  2026-03-31T00:00:00               Voluntario
# 3  Semestre 01  2026-04-20T00:00:00               Voluntario
# 4  Semestre 01  2026-05-11T00:00:00               Voluntario
#
#                              Observacion_cancelacion  Edad Genero
# 0  El estudiante se realiza retiro voluntario de ...    20      M
# 1  El estudiante aplaza su semestre por motivos p...    18      M
# 2  El estudiante decide retirarse por dificultade...    23      M
# 3  La estudiante se retira del programa  por moti...    25      F
# 4  La estudiante se retira del programa por temas...    32      F

# %%
def separar_sede_programa(nombre):
    partes = nombre.split(' - ')
    sede = partes[0].strip()
    
    # Si hay 3 partes, la del medio es jornada (ignorar)
    # Si hay 2 partes, directo sede - programa
    programa = partes[-1].strip()
    
    return sede, programa

df[['Sede', 'Nombre_programa_limpio']] = df['Nombre_programa'].apply(
    lambda x: pd.Series(separar_sede_programa(x))
)
df.drop(columns=['Nombre_programa'], inplace=True)
df.head()
# Out:
#   Nombre_periodo Nombre_nivel    Fecha_cancelacion Nombre_causa_cancelacion  \
# 0         2026-1  Semestre 01  2026-03-09T00:00:00               Voluntario
# 1         2026-1  Semestre 01  2026-03-13T00:00:00             Aplazamiento
# 2         2026-1  Semestre 01  2026-03-31T00:00:00               Voluntario
# 3         2026-1  Semestre 01  2026-04-20T00:00:00               Voluntario
# 4         2026-1  Semestre 01  2026-05-11T00:00:00               Voluntario
#
#                              Observacion_cancelacion  Edad Genero      Sede  \
# 0  El estudiante se realiza retiro voluntario de ...    20      M  BASTIDAS
# 1  El estudiante aplaza su semestre por motivos p...    18      M  BASTIDAS
# 2  El estudiante decide retirarse por dificultade...    23      M  BASTIDAS
# 3  La estudiante se retira del programa  por moti...    25      F  BASTIDAS
# 4  La estudiante se retira del programa por temas...    32      F  BASTIDAS
#
#                             Nombre_programa_limpio
# 0  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 1  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 2  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 3  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 4  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS

# %%
# Convertir a datetime, manejando errores
df['Fecha_cancelacion'] = pd.to_datetime(df['Fecha_cancelacion'], errors='coerce')
df.head()
# Out:
#   Nombre_periodo Nombre_nivel Fecha_cancelacion Nombre_causa_cancelacion  \
# 0         2026-1  Semestre 01        2026-03-09               Voluntario
# 1         2026-1  Semestre 01        2026-03-13             Aplazamiento
# 2         2026-1  Semestre 01        2026-03-31               Voluntario
# 3         2026-1  Semestre 01        2026-04-20               Voluntario
# 4         2026-1  Semestre 01        2026-05-11               Voluntario
#
#                              Observacion_cancelacion  Edad Genero      Sede  \
# 0  El estudiante se realiza retiro voluntario de ...    20      M  BASTIDAS
# 1  El estudiante aplaza su semestre por motivos p...    18      M  BASTIDAS
# 2  El estudiante decide retirarse por dificultade...    23      M  BASTIDAS
# 3  La estudiante se retira del programa  por moti...    25      F  BASTIDAS
# 4  La estudiante se retira del programa por temas...    32      F  BASTIDAS
#
#                             Nombre_programa_limpio
# 0  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 1  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 2  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 3  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 4  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS

# %%
print(df['Nombre_causa_cancelacion'].unique())
df['Observacion_cancelacion'].unique()
# Out:
# ['Voluntario' 'Aplazamiento'
#  'Pérdida de la condición de estudiante por inasistencia injustificada'
#  'Enfermedad' 'Cambio de Institución' 'Otra' 'Dificultades Económicas'
#  'Dificultades en el Horario' 'Cambio de Domicilio']
# array(['El estudiante se realiza retiro voluntario de la institución.',
#        'El estudiante aplaza su semestre por motivos personales.',
#        'El estudiante decide retirarse por dificultades laborales que le impiden seguir en la institución.',
#        'La estudiante se retira del programa  por motivos personales y familiares.',
#        'La estudiante se retira del programa por temas laborales.',
#        'La estudiante decide retirarse ya que inició en otra universidad.',
#        'El estudiante decide retirarse por motivos de índole personal y a un cambio en mi proyecto de vida académico, el cual me llevará a iniciar estudios en un área distinta.',
#        'La estudiante realiza aplazamiento del semestre.',
#        'Se cancela la matricula según circular 011-2026',
#        'La estudiante realiza retiro voluntario por enfermedad.',
#        'La estudiante aplaza su segundo semestre por motivos laborales.',
#        'La estudiante decide retirarse voluntariamente por motivos personales ajenos a su voluntad.',
#        'La estudiante se retira del programa, ya que desea aspirar a otro programa profesional.',
#        'La estudiante decide cancelar el semestre por motivos de saludo.',
#        'La estudiante decide retirarse del programa por responsabilidades de cabeza de hogar.\r\n',
#        'La estudiante se retira por dificultades en el horario ya que estudia otro programa en otra universidad.',
#        'La estudiante se retira del programa por motivos laborales.',
#        'La estudiante se retira del programa ya que estudia en otra institución.',
#        'La estudiante cancela el programa por motivos personales.',
#        'Estudiante retirado mediante la circular 011-2026',
#        "El estudiante desiste por ''falta de tiempo y dificultades en mi situación financiera actual, lo cual me impide continuar con mis estudios de manera adecuada.''",
#        'El estudiante solicita retiro voluntario por asuntos laborales.',
#        'La estudiante solicita retiro voluntario ya que se cambiará de ciudad.',
#        'El estudiante solicita retiro voluntario ya que el horario no le permite estudiar.',
#        'El estudiante solicita aplazamiento del semestre por motivos laborales.',
#        'La estudiante hace retiro voluntario de la institución ya que salió admitida en otra universidad.',
#        'El estudiante aplaza el semestre por motivos laborales.',
#        'El estudiante se retira de la carrera ya que cambio de ciudad.',
#        'El estudiante decide aplazar el semestre  por\r\nrazones personales y familiares, tuvo que ausentarme de santa marta, por un largo periodo lo cual me impide asistir a las clases este semestre.',
#        'La estudiante decide aplazar el semestre por asuntos personales debe irse de la ciudad 3 meses.',
#        'La estudiante aplaza el semestre por motivos laborales',
#        'La estudiante decide aplazar el semestre por motivos personales.',
#        'El estudiante aplaza semestre por motivos laborales',
#        'El estudiante congela el semestre por motivos de viaje.',
#        'La estudiante se retira del programa ya que no cumple con los requisitos de politica de gratuidad',
#        'La estudiante decide aplazar el semestre por motivos laborales',
#        'La estudiante aplaza el semestre por motivos laborales.',
#        'el estudiante hace retiro de la institución por motivos personales',
#        'La estudiante solicita retiro ya que se va de la ciudad y no le es posible terminar su formación.',
#        'La estudiante decide retirarse voluntariamente debido a razones personales y laborales que requieren de su atención y compromiso.',
#        'La estudiante se retira del programa por cambio de programa.',
#        'La estudiante se retira del programa por cambio de ciudad.',
#        'La estudiante se retiró del programa por motivos maternales.',
#        'Se cancela la matricula según resolución 011-2026 ',
#        'Se cancela la matricula según circular 011-2026 ',
#        ' los horarios, evidencio que no son compatibles con mi jornada laboral actual, lo cual me impide asistir y cumplir adecuadamente con el programa.',
#        'La estudiante se retira por calamidad de fuerza mayor.',
#        'El estudiante realiza aplazamiento del semestre por motivos laborales.',
#        'La estudiante se retira por motivos personales.',
#        'Por ser paciente oncologica, la estudiante decide retirarse.',
#        'La estudiante se retira por falta de interes en el programa.',
#        'Estudiante se retira por motivos personales',
#        'La estudiante realiza aplazamiento del semestre por motivos laborales',
#        'Cambio de programa ',
#        'La estudiante desea aplazar el semestre por motivos personales y laborales.\r\n',
#        'La estudiante aplaza semestre ya que realizó cambio de ciudad.',
#        'El estudiante desiste del programa por motivos laborales.',
#        'El estudiante se retira ya que realizará el cambio de programa.',
#        'Debido a mi horario laboral y asuntos económicos, ya que trabajo de manera continua todo el día se me ha sido imposible cumplir con las responsabilidades académicas y laborales de manera simultánea.',
#        ' La estudiante decide pausar el semestre ya que puede cumplir con sus responsabilidades académicas y necesita  tiempo para cuidar de mi hija. '],
#       dtype=object)

# %%
import re

def clasificar_causa(observacion):
    if pd.isna(observacion) or str(observacion).strip() == '':
        return 'Sin información'
    
    obs = str(observacion).lower()
    
    # Orden importa: de más específico a más general
    if any(p in obs for p in ['circular 011', 'resolución 011']):
        return 'Cancelación administrativa'
    
    if any(p in obs for p in ['oncolog', 'enfermedad', 'salud', 'saludo', 'calamidad']):
        return 'Salud'
    
    if any(p in obs for p in ['matern', 'hija', 'hijo', 'cabeza de hogar', 'familiar']):
        return 'Responsabilidad familiar'
    
    if any(p in obs for p in ['otra universidad', 'otra institución', 'admitida en otra', 'cambio de programa', 'cambio de carrera', 'otro programa']):
        return 'Cambio de institución o programa'
    
    if any(p in obs for p in ['cambio de ciudad', 'se va de la ciudad', 'ausentarme', 'irse de la ciudad', 'cambió de ciudad']):
        return 'Cambio de ciudad'
    
    if any(p in obs for p in ['laboral', 'trabajo', 'horario', 'jornada laboral', 'económic', 'financier']):
        return 'Razones laborales o económicas'
    
    if any(p in obs for p in ['aplaz', 'congela', 'pausa', 'postergar']):
        return 'Aplazamiento'
    
    if any(p in obs for p in ['falta de interés', 'falta de interes', 'no le gusta', 'no cumple', 'gratuidad']):
        return 'Deserción por desinterés o requisitos'
    
    if any(p in obs for p in ['personal', 'voluntari', 'desiste', 'retiro']):
        return 'Motivos personales'
    
    return 'Otro'


df['Causa_definitiva'] = df['Observacion_cancelacion'].apply(clasificar_causa)

# %%
df['Causa_definitiva'].value_counts()
# Out:
# Causa_definitiva
# Razones laborales o económicas           23
# Cancelación administrativa               21
# Motivos personales                        9
# Cambio de institución o programa          8
# Responsabilidad familiar                  5
# Cambio de ciudad                          5
# Aplazamiento                              4
# Salud                                     4
# Deserción por desinterés o requisitos     2
# Name: count, dtype: int64

# %%
df.groupby(['Nombre_causa_cancelacion', 'Causa_definitiva']).size().reset_index(name='conteo')
# Out:
#                              Nombre_causa_cancelacion  \
# 0                                        Aplazamiento
# 1                                        Aplazamiento
# 2                                        Aplazamiento
# 3                                        Aplazamiento
# 4                                        Aplazamiento
# 5                                 Cambio de Domicilio
# 6                               Cambio de Institución
# 7                             Dificultades Económicas
# 8                          Dificultades en el Horario
# 9                                          Enfermedad
# 10                                               Otra
# 11                                               Otra
# 12                                               Otra
# 13  Pérdida de la condición de estudiante por inas...
# 14                                         Voluntario
# 15                                         Voluntario
# 16                                         Voluntario
# 17                                         Voluntario
# 18                                         Voluntario
# 19                                         Voluntario
# 20                                         Voluntario
#
#                          Causa_definitiva  conteo
# 0                            Aplazamiento       4
# 1                        Cambio de ciudad       1
# 2                      Motivos personales       1
# 3          Razones laborales o económicas      12
# 4                Responsabilidad familiar       1
# 5                        Cambio de ciudad       3
# 6        Cambio de institución o programa       1
# 7          Razones laborales o económicas       1
# 8          Razones laborales o económicas       2
# 9                                   Salud       2
# 10       Cambio de institución o programa       1
# 11                     Motivos personales       1
# 12               Responsabilidad familiar       2
# 13             Cancelación administrativa      21
# 14                       Cambio de ciudad       1
# 15       Cambio de institución o programa       6
# 16  Deserción por desinterés o requisitos       2
# 17                     Motivos personales       7
# 18         Razones laborales o económicas       8
# 19               Responsabilidad familiar       2
# 20                                  Salud       2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre_periodo            81 non-null     object
#  1   Nombre_nivel              81 non-null     object
#  2   Fecha_cancelacion         81 non-null     datetime64[ns]
#  3   Nombre_causa_cancelacion  81 non-null     object
#  4   Observacion_cancelacion   81 non-null     object
#  5   Edad                      81 non-null     int64
#  6   Genero                    81 non-null     object
#  7   Sede                      81 non-null     object
#  8   Nombre_programa_limpio    81 non-null     object
#  9   Causa_definitiva          81 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 6.5+ KB

# %% [markdown]
# # Analisis exploratorio

# %% [markdown]
# ### Bloque 1 — Configuración e imports

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# ── Paleta institucional USM ──────────────────────────
USM_PRIMARIOS   = ['#1C5DA9', '#93D3F5', '#63C2CA']
USM_SECUNDARIOS = [ '#E50371','#13B2B2', '#219BD6', '#F5B7D4',
                   '#058389', '#CDE9F6', '#1E3256']
USM_TODOS = USM_PRIMARIOS + USM_SECUNDARIOS

# Colores de uso frecuente
AZUL       = '#1C5DA9'
AZUL_CLARO = '#93D3F5'
VERDE_AGUA = '#63C2CA'
OSCURO     = '#1E3256'

sns.set_theme(style='whitegrid')
plt.rcParams.update({
    'figure.dpi': 130,
    'font.family': 'DejaVu Sans',   # proxy de Calibri en notebooks
    'axes.titlesize': 13,
    'axes.labelsize': 11,
    'axes.titlecolor': OSCURO,
    'axes.labelcolor': OSCURO,
    'axes.edgecolor': '#cccccc',
    'grid.color': '#e8e8e8',
    'text.color': OSCURO,
})

print('✅ Paleta USM cargada')
# Out:
# ✅ Paleta USM cargada

# %% [markdown]
# ### Bloque 2 — Resumen general

# %%
print("=" * 56)
print("  RESUMEN GENERAL — CANCELACIONES ACADÉMICAS USM")
print("=" * 56)
print(f"  Total estudiantes (únicos)    {TOTAL_EST:>8,}")
print(f"  Total cancelaciones           {TOTAL_CANCEL:>8,}")
print(f"  Tasa global de cancelación    {TASA_GLOBAL:>7.1f}%")
print(f"  Programas únicos              {df['Nombre_programa_limpio'].nunique():>8}")
print(f"  Sedes únicas                  {df['Sede'].nunique():>8}")
print(f"  Causas clasificadas           {df['Causa_definitiva'].nunique():>8}")
print(f"  Con edad registrada           {df['Edad'].notna().sum():>8,}  ({df['Edad'].notna().mean()*100:.1f}%)")
print(f"  Con género registrado         {df['Genero'].notna().sum():>8,}  ({df['Genero'].notna().mean()*100:.1f}%)")
print(f"  Edad promedio                 {df['Edad'].mean():>8.1f} años")
print(f"  Rango de edad                 {int(df['Edad'].min()):>4} – {int(df['Edad'].max())} años")
# Out:
# ========================================================
#   RESUMEN GENERAL — CANCELACIONES ACADÉMICAS USM
# ========================================================
#   Total estudiantes (únicos)         881
#   Total cancelaciones                 81
#   Tasa global de cancelación        9.2%
#   Programas únicos                     5
#   Sedes únicas                         5
#   Causas clasificadas                  9
#   Con edad registrada                 81  (100.0%)
#   Con género registrado               81  (100.0%)
#   Edad promedio                     24.1 años
#   Rango de edad                    0 – 56 años

# %% [markdown]
# ### Bloque 3 — Cancelaciones por programa

# %%
fig, ax = plt.subplots(figsize=(12, 5))

est_por_programa = df_est.groupby('Nombre_programa_limpio')['Numero_identificacion'].nunique().reset_index(name='Total_est')
cancel_por_programa = df.groupby('Nombre_programa_limpio').size().reset_index(name='Cancelaciones')
merged = cancel_por_programa.merge(est_por_programa, on='Nombre_programa_limpio', how='left')
merged['Tasa'] = (merged['Cancelaciones'] / merged['Total_est'] * 100).round(1)
merged = merged.sort_values('Tasa', ascending=True)

bars = ax.barh(merged['Nombre_programa_limpio'], merged['Tasa'],
               color=AZUL, edgecolor='white', height=0.6)

for bar, tasa, cancel, total in zip(bars, merged['Tasa'], merged['Cancelaciones'], merged['Total_est']):
    ax.text(tasa + 0.2, bar.get_y() + bar.get_height()/2,
            f'{tasa}%  ({cancel} / {total})', va='center', fontsize=9, color=OSCURO)

ax.axvline(TASA_GLOBAL, color=MAGENTA, linewidth=1.5, linestyle='--', label=f'Tasa global {TASA_GLOBAL}%')
ax.legend(fontsize=9)
ax.set_xlabel('Tasa de cancelación (%)')
ax.set_title('Cancelaciones por Programa — Tasa vs Estudiantes Matriculados', fontweight='bold', pad=12)
ax.invert_yaxis()
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
merged.sort_values('Tasa', ascending=False).reset_index(drop=True)
# Out:
#                               Nombre_programa_limpio  Cancelaciones  \
# 0       TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS             13
# 1  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...             27
# 2    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS             15
# 3                    TECNOLOGÍA EN MARKETING DIGITAL             17
# 4   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS              9
#
#    Total_est  Tasa
# 0         76  17.1
# 1        176  15.3
# 2        210   7.1
# 3        267   6.4
# 4        153   5.9

# %% [markdown]
# ### Bloque 4 — Cancelaciones por sede

# %%
fig, ax = plt.subplots(figsize=(9, 4))

est_por_sede = df_est.groupby('Sede')['Numero_identificacion'].nunique().reset_index(name='Total_est')
cancel_por_sede = df.groupby('Sede').size().reset_index(name='Cancelaciones')
merged = cancel_por_sede.merge(est_por_sede, on='Sede', how='left')
merged['Tasa'] = (merged['Cancelaciones'] / merged['Total_est'] * 100).round(1)
merged = merged.sort_values('Tasa', ascending=False)

bars = ax.bar(merged['Sede'], merged['Tasa'],
              color=VERDE_AGUA, edgecolor='white', width=0.55)

for bar, tasa, cancel, total in zip(bars, merged['Tasa'], merged['Cancelaciones'], merged['Total_est']):
    ax.text(bar.get_x() + bar.get_width()/2, tasa + 0.3,
            f'{tasa}%\n({cancel}/{total})', ha='center', fontsize=8, color=OSCURO)

ax.axhline(TASA_GLOBAL, color=MAGENTA, linewidth=1.5, linestyle='--', label=f'Tasa global {TASA_GLOBAL}%')
ax.legend(fontsize=9)
ax.set_title('Cancelaciones por Sede — Tasa vs Estudiantes Matriculados', fontweight='bold', pad=12)
ax.set_xlabel('Sede')
ax.set_ylabel('Tasa de cancelación (%)')
ax.tick_params(axis='x', rotation=25)
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
merged.sort_values('Tasa', ascending=False).reset_index(drop=True)
# Out:
#        Sede  Cancelaciones  Total_est  Tasa
# 0     MINCA              8         63  12.7
# 1      INEM             59        570  10.4
# 2  BASTIDAS              7         71   9.9
# 3  BURITACA              5         87   5.7
# 4  PESCAITO              2         90   2.2

# %%
fig, ax = plt.subplots(figsize=(7, 7))

conteo_sede = df['Sede'].value_counts()
ax.pie(conteo_sede.values,
       labels=conteo_sede.index,
       autopct='%1.1f%%',
       colors=USM_TODOS[:len(conteo_sede)],
       startangle=140,
       wedgeprops={'edgecolor': 'white', 'linewidth': 1.5})

ax.set_title('Distribución porcentual por Sede', fontweight='bold', pad=16)
plt.tight_layout()
plt.show()

# Tabla resumen
conteo_sede = df['Sede'].value_counts().reset_index()
conteo_sede.columns = ['Sede', 'Cancelaciones']
est_sede = df_est.groupby('Sede')['Numero_identificacion'].nunique().reset_index(name='Total_est')
conteo_sede = conteo_sede.merge(est_sede, on='Sede', how='left')
conteo_sede['Tasa'] = (conteo_sede['Cancelaciones'] / conteo_sede['Total_est'] * 100).round(1).astype(str) + '%'
display(conteo_sede.sort_values('Cancelaciones', ascending=False).reset_index(drop=True))
# Out:
#        Sede  Cancelaciones  Total_est   Tasa
# 0      INEM             59        570  10.4%
# 1     MINCA              8         63  12.7%
# 2  BASTIDAS              7         71   9.9%
# 3  BURITACA              5         87   5.7%
# 4  PESCAITO              2         90   2.2%

# %% [markdown]
# ### Bloque 5 — Cancelaciones por causa definitiva

# %%
fig, ax = plt.subplots(figsize=(11, 5))

conteo_causa = df['Causa_definitiva'].value_counts().reset_index()
conteo_causa.columns = ['Causa_definitiva', 'Cancelaciones']
conteo_causa['Tasa'] = (conteo_causa['Cancelaciones'] / TOTAL_EST * 100).round(2)
conteo_causa = conteo_causa.sort_values('Tasa', ascending=True)

bars = ax.barh(conteo_causa['Causa_definitiva'], conteo_causa['Tasa'],
               color=USM_TODOS[:len(conteo_causa)],
               edgecolor='white', height=0.6)

for bar, tasa, cancel in zip(bars, conteo_causa['Tasa'], conteo_causa['Cancelaciones']):
    ax.text(tasa + 0.02, bar.get_y() + bar.get_height()/2,
            f'{tasa}%  ({cancel} de {TOTAL_EST:,})', va='center', fontsize=9, color=OSCURO)

ax.set_title('Cancelaciones por Causa — Tasa sobre Total de Estudiantes', fontweight='bold', pad=12)
ax.set_xlabel('Tasa (%)')
ax.invert_yaxis()
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
conteo_causa.sort_values('Tasa', ascending=False).reset_index(drop=True)
# Out:
#                         Causa_definitiva  Cancelaciones  Tasa
# 0         Razones laborales o económicas             23  2.61
# 1             Cancelación administrativa             21  2.38
# 2                     Motivos personales              9  1.02
# 3       Cambio de institución o programa              8  0.91
# 4               Responsabilidad familiar              5  0.57
# 5                       Cambio de ciudad              5  0.57
# 6                           Aplazamiento              4  0.45
# 7                                  Salud              4  0.45
# 8  Deserción por desinterés o requisitos              2  0.23

# %%
fig, ax = plt.subplots(figsize=(8, 8))

conteo_causa = df['Causa_definitiva'].value_counts()
ax.pie(conteo_causa.values,
       labels=conteo_causa.index,
       autopct='%1.1f%%',
       colors=USM_TODOS[:len(conteo_causa)],
       startangle=140,
       wedgeprops={'edgecolor': 'white', 'linewidth': 1.5},
       textprops={'fontsize': 9})

ax.set_title('Distribución porcentual por Causa', fontweight='bold', pad=16)
plt.tight_layout()
plt.show()

# Tabla resumen
conteo_causa = df['Causa_definitiva'].value_counts().reset_index()
conteo_causa.columns = ['Causa', 'Cancelaciones']
conteo_causa['% del total estud.'] = (conteo_causa['Cancelaciones'] / TOTAL_EST * 100).round(2).astype(str) + '%'
conteo_causa['% de cancelados'] = (conteo_causa['Cancelaciones'] / TOTAL_CANCEL * 100).round(1).astype(str) + '%'
display(conteo_causa.sort_values('Cancelaciones', ascending=False).reset_index(drop=True))
# Out:
#                                    Causa  Cancelaciones % del total estud.  \
# 0         Razones laborales o económicas             23              2.61%
# 1             Cancelación administrativa             21              2.38%
# 2                     Motivos personales              9              1.02%
# 3       Cambio de institución o programa              8              0.91%
# 4               Responsabilidad familiar              5              0.57%
# 5                       Cambio de ciudad              5              0.57%
# 6                           Aplazamiento              4              0.45%
# 7                                  Salud              4              0.45%
# 8  Deserción por desinterés o requisitos              2              0.23%
#
#   % de cancelados
# 0           28.4%
# 1           25.9%
# 2           11.1%
# 3            9.9%
# 4            6.2%
# 5            6.2%
# 6            4.9%
# 7            4.9%
# 8            2.5%

# %% [markdown]
# ### Bloque 6 — Análisis de edad

# %%
fig, ax = plt.subplots(figsize=(9, 4))

ax.hist(df['Edad'].dropna(), bins=20,
        color=AZUL, edgecolor='white', alpha=0.9)
ax.axvline(df['Edad'].mean(), color=MAGENTA, linewidth=2,
           linestyle='--', label=f"Promedio: {df['Edad'].mean():.1f} años")
ax.axvline(df['Edad'].median(), color=VERDE, linewidth=2,
           linestyle=':', label=f"Mediana: {df['Edad'].median():.1f} años")

ax.set_title('Distribución de Edades', fontweight='bold', pad=12)
ax.set_xlabel('Edad (años)')
ax.set_ylabel('Frecuencia')
ax.legend()
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
df['Edad'].describe().rename({
    'count':'Registros','mean':'Promedio','std':'Desv. estándar',
    'min':'Mínimo','25%':'P25','50%':'Mediana','75%':'P75','max':'Máximo'
}).round(1).to_frame('Edad')
# Out:
#                 Edad
# Registros       81.0
# Promedio        24.1
# Desv. estándar   9.1
# Mínimo           0.0
# P25             18.0
# Mediana         21.0
# P75             27.0
# Máximo          56.0

# %%
fig, ax = plt.subplots(figsize=(10, 5))

df_edad = df[df['Edad'].notna()]
orden = df_edad.groupby('Causa_definitiva')['Edad'].median().sort_values().index.tolist()

sns.boxplot(data=df_edad, y='Causa_definitiva', x='Edad',
            order=orden, palette=USM_TODOS[:len(orden)],
            width=0.55, linewidth=1.2, ax=ax)

ax.set_title('Distribución de Edad por Causa', fontweight='bold', pad=12)
ax.set_xlabel('Edad (años)')
ax.set_ylabel('')
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
df_edad.groupby('Causa_definitiva')['Edad'] \
  .agg(Registros='count', Promedio='mean', Mediana='median',
       Minimo='min', Maximo='max', Desv='std') \
  .round(1).sort_values('Promedio', ascending=False)
# Out:
#                                        Registros  Promedio  Mediana  Minimo  \
# Causa_definitiva
# Deserción por desinterés o requisitos          2      33.5     33.5      17
# Salud                                          4      33.5     35.5      19
# Razones laborales o económicas                23      25.3     23.0      17
# Aplazamiento                                   4      25.0     24.5      18
# Cancelación administrativa                    21      24.6     21.0      16
# Responsabilidad familiar                       5      22.6     25.0       0
# Cambio de institución o programa               8      21.2     19.0      17
# Motivos personales                             9      19.2     19.0      17
# Cambio de ciudad                               5      18.8     18.0      17
#
#                                        Maximo  Desv
# Causa_definitiva
# Deserción por desinterés o requisitos      50  23.3
# Salud                                      44  12.1
# Razones laborales o económicas             56   8.6
# Aplazamiento                               33   7.6
# Cancelación administrativa                 45   9.1
# Responsabilidad familiar                   42  15.0
# Cambio de institución o programa           35   6.0
# Motivos personales                         22   1.5
# Cambio de ciudad                           23   2.5

# %%
fig, ax = plt.subplots(figsize=(11, 5))

df_edad = df[df['Edad'].notna()]
orden_prog = df_edad.groupby('Nombre_programa_limpio')['Edad'].median().sort_values().index.tolist()

sns.boxplot(data=df_edad, y='Nombre_programa_limpio', x='Edad',
            order=orden_prog, palette=USM_PRIMARIOS * 5,
            width=0.55, linewidth=1.2, ax=ax)

ax.set_title('Distribución de Edad por Programa', fontweight='bold', pad=12)
ax.set_xlabel('Edad (años)')
ax.set_ylabel('')
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
df_edad.groupby('Nombre_programa_limpio')['Edad'] \
  .agg(Registros='count', Promedio='mean', Mediana='median',
       Minimo='min', Maximo='max') \
  .round(1).sort_values('Promedio', ascending=False)
# Out:
#                                                     Registros  Promedio  \
# Nombre_programa_limpio
# TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS            9      28.8
# TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS               13      25.5
# TECNOLOGÍA EN MARKETING DIGITAL                            17      24.1
# TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y DE...         27      22.9
# TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS            15      22.2
#
#                                                     Mediana  Minimo  Maximo
# Nombre_programa_limpio
# TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS       25.0      17      50
# TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS           20.0      17      45
# TECNOLOGÍA EN MARKETING DIGITAL                        22.0      17      44
# TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y DE...     21.0       0      56
# TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS        20.0      17      34

# %% [markdown]
# ### Bloque 7 — Análisis de género

# %%
genero_map = {'M': 'Masculino', 'F': 'Femenino'}
df['Genero_label'] = df['Genero'].map(genero_map).fillna('Sin dato')

est_gen = df_est['Genero'].map(genero_map).fillna('Sin dato').value_counts()
cancel_gen = df['Genero_label'].value_counts()
tasa_gen = (cancel_gen / est_gen * 100).round(1)

fig, ax = plt.subplots(figsize=(6, 6))

labels = [f'{g}\n({t}%)' for g, t in zip(cancel_gen.index, tasa_gen.values)]

ax.pie(cancel_gen.values,
       labels=labels,
       colors=[AZUL, MAGENTA, '#cccccc'],
       startangle=90,
       wedgeprops={'edgecolor': 'white'})

ax.set_title('Cancelaciones por Género — Tasa vs Matriculados', fontweight='bold', pad=12)
plt.tight_layout()
plt.show()

resumen_gen = cancel_gen.reset_index(name='Cancelaciones')
resumen_gen['Total_est'] = resumen_gen['Genero_label'].map(est_gen)
resumen_gen['Tasa'] = (resumen_gen['Cancelaciones'] / resumen_gen['Total_est'] * 100).round(1).astype(str) + '%'
resumen_gen.sort_values('Cancelaciones', ascending=False).reset_index(drop=True)
# Out:
#   Genero_label  Cancelaciones  Total_est   Tasa
# 0     Femenino             56        554  10.1%
# 1    Masculino             25        328   7.6%

# %%
fig, ax = plt.subplots(figsize=(11, 5))

cancel_gp = df.groupby(['Nombre_programa_limpio', 'Genero_label']).size().reset_index(name='Cancelaciones')
est_gp = df_est.copy()
est_gp['Genero_label'] = est_gp['Genero'].map(genero_map).fillna('Sin dato')
est_gp = est_gp.groupby(['Nombre_programa_limpio', 'Genero_label'])['Numero_identificacion'].nunique().reset_index(name='Total_est')

merged_gp = cancel_gp.merge(est_gp, on=['Nombre_programa_limpio', 'Genero_label'], how='right').fillna(0)
merged_gp['Tasa'] = (merged_gp['Cancelaciones'] / merged_gp['Total_est'] * 100).round(1)

pivot_gp = merged_gp.pivot(index='Nombre_programa_limpio', columns='Genero_label', values='Tasa').fillna(0)
pivot_gp = pivot_gp[['Femenino', 'Masculino']] if 'Femenino' in pivot_gp and 'Masculino' in pivot_gp else pivot_gp

pivot_gp.plot(kind='barh', ax=ax, color=[AZUL, MAGENTA], edgecolor='white', width=0.65)

for i in range(len(pivot_gp)):
    for j, col in enumerate(pivot_gp.columns):
        val = pivot_gp.iloc[i, j]
        if val > 0:
            ax.text(val + 0.2, i + (j - 0.5) * 0.3, f'{val:.1f}%', va='center', fontsize=7, color='#333333')

ax.set_title('Tasa de Cancelación por Programa y Género (%)', fontweight='bold', pad=12)
ax.set_xlabel('Tasa (%)')
ax.invert_yaxis()
ax.spines[['top','right']].set_visible(False)
ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

# Tabla resumen
display(merged_gp.sort_values(['Nombre_programa_limpio', 'Genero_label']).reset_index(drop=True))
# Out:
#                               Nombre_programa_limpio Genero_label  \
# 0    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS     Femenino
# 1    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS    Masculino
# 2       TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS     Femenino
# 3       TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS    Masculino
# 4   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS     Femenino
# 5   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS    Masculino
# 6  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...     Femenino
# 7  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...    Masculino
# 8                    TECNOLOGÍA EN MARKETING DIGITAL     Femenino
# 9                    TECNOLOGÍA EN MARKETING DIGITAL    Masculino
#
#    Cancelaciones  Total_est  Tasa
# 0            6.0        116   5.2
# 1            9.0         94   9.6
# 2           13.0         73  17.8
# 3            0.0          3   0.0
# 4            5.0         82   6.1
# 5            4.0         71   5.6
# 6           21.0        138  15.2
# 7            6.0         38  15.8
# 8           11.0        145   7.6
# 9            6.0        122   4.9

# %%
fig, ax = plt.subplots(figsize=(11, 5))

cancel_gc = df.groupby(['Causa_definitiva', 'Genero_label']).size().reset_index(name='Cancelaciones')
cancel_gc['Tasa'] = (cancel_gc['Cancelaciones'] / TOTAL_EST * 100).round(2)

pivot_gc = cancel_gc.pivot(index='Causa_definitiva', columns='Genero_label', values='Tasa').fillna(0)
if 'Femenino' in pivot_gc and 'Masculino' in pivot_gc:
    pivot_gc = pivot_gc[['Femenino', 'Masculino']]

pivot_gc.plot(kind='barh', ax=ax, color=[AZUL, MAGENTA, '#cccccc'], edgecolor='white', width=0.65)

ax.set_title('Tasa de Cancelación por Causa y Género (% del total estud.)', fontweight='bold', pad=12)
ax.set_xlabel('Tasa (%)')
ax.invert_yaxis()
ax.spines[['top','right']].set_visible(False)
ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

# Tabla resumen
cancel_gc = df.groupby(['Causa_definitiva', 'Genero_label']).size().reset_index(name='Cancelaciones')
cancel_gc['Tasa'] = (cancel_gc['Cancelaciones'] / TOTAL_EST * 100).round(2).astype(str) + '%'
display(cancel_gc.sort_values(['Causa_definitiva', 'Genero_label']).reset_index(drop=True))
# Out:
#                          Causa_definitiva Genero_label  Cancelaciones   Tasa
# 0                            Aplazamiento     Femenino              2  0.23%
# 1                            Aplazamiento    Masculino              2  0.23%
# 2                        Cambio de ciudad     Femenino              4  0.45%
# 3                        Cambio de ciudad    Masculino              1  0.11%
# 4        Cambio de institución o programa     Femenino              6  0.68%
# 5        Cambio de institución o programa    Masculino              2  0.23%
# 6              Cancelación administrativa     Femenino             16  1.82%
# 7              Cancelación administrativa    Masculino              5  0.57%
# 8   Deserción por desinterés o requisitos     Femenino              2  0.23%
# 9                      Motivos personales     Femenino              5  0.57%
# 10                     Motivos personales    Masculino              4  0.45%
# 11         Razones laborales o económicas     Femenino             13  1.48%
# 12         Razones laborales o económicas    Masculino             10  1.14%
# 13               Responsabilidad familiar     Femenino              4  0.45%
# 14               Responsabilidad familiar    Masculino              1  0.11%
# 15                                  Salud     Femenino              4  0.45%

# %% [markdown]
# ### Bloque 8 — Heatmap sede × programa

# %%
df.columns
# Out:
# Index(['Nombre_periodo', 'Nombre_nivel', 'Fecha_cancelacion',
#        'Nombre_causa_cancelacion', 'Observacion_cancelacion', 'Edad', 'Genero',
#        'Sede', 'Nombre_programa_limpio', 'Causa_definitiva', 'Genero_label'],
#       dtype='object')

# %%
from matplotlib.colors import LinearSegmentedColormap

usm_cmap = LinearSegmentedColormap.from_list('usm', ['#FFFFFF', AZUL_CLARO, AZUL])

# Matriz de cancelaciones
cancel_mat = df.groupby(['Sede', 'Nombre_programa_limpio']).size().reset_index(name='Cancelaciones')

# Totales de estudiantes por sede x programa
est_mat = df_est.groupby(['Sede', 'Nombre_programa_limpio'])['Numero_identificacion'].nunique().reset_index(name='Total_est')

merged = cancel_mat.merge(est_mat, on=['Sede', 'Nombre_programa_limpio'], how='right').fillna(0)
merged['Tasa'] = (merged['Cancelaciones'] / merged['Total_est'] * 100).round(1)

pivot = merged.pivot(index='Sede', columns='Nombre_programa_limpio', values='Tasa')

fig, ax = plt.subplots(figsize=(10, 5))
im = ax.imshow(pivot.values, cmap=usm_cmap, aspect='auto', vmin=0)

for i in range(pivot.shape[0]):
    for j in range(pivot.shape[1]):
        val = pivot.values[i, j]
        txt = f'{val:.1f}%' if val > 0 else '-'
        ax.text(j, i, txt, ha='center', va='center', fontsize=9,
                color='white' if val > pivot.values.max()*0.6 else OSCURO)

ax.set_xticks(range(pivot.shape[1]))
ax.set_yticks(range(pivot.shape[0]))
ax.set_xticklabels(pivot.columns, fontsize=8, rotation=25, ha='right')
ax.set_yticklabels(pivot.index, fontsize=9)
ax.set_title('Tasa de Cancelación por Sede y Programa (%)', fontweight='bold', pad=12)
fig.colorbar(im, ax=ax, shrink=0.8, label='%')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bloque 8 — Evolución por fecha (3 cortes)

# %%
import pandas as pd

# ── Grupos con fechas diferenciadas ──────────────────
PROGRAMAS_GRUPO_B = ['TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS']
SEDES_GRUPO_B     = ['MINCA', 'BURITACA']

# ── Rangos por grupo ──────────────────────────────────
CORTES_A = pd.to_datetime([
    '2026-02-01', '2026-04-01', '2026-05-13', '2026-06-25'
])
ETIQUETAS_A = [
    'Seguimiento 1',
    'Seguimiento 2',
    'Seguimiento 3',
]

CORTES_B = pd.to_datetime([
    '2026-04-06', '2026-05-10', '2026-06-13', '2026-07-26'
])
ETIQUETAS_B = [
    'Seguimiento 1',
    'Seguimiento 2',
    'Seguimiento 3',
]

# ── Identificar a qué grupo pertenece cada fila ───────
df['Fecha_cancelacion'] = pd.to_datetime(df['Fecha_cancelacion'], errors='coerce')

es_grupo_b = (
    df['Nombre_programa_limpio'].isin(PROGRAMAS_GRUPO_B) |
    df['Sede'].isin(SEDES_GRUPO_B)
)

# ── Asignar seguimiento según grupo ───────────────────
def asignar_seguimiento(fecha, cortes, etiquetas):
    if pd.isna(fecha):
        return None
    for i in range(len(etiquetas)):
        if cortes[i] <= fecha < cortes[i + 1]:
            return etiquetas[i]
    return None

df['Seguimiento'] = [
    asignar_seguimiento(
        row['Fecha_cancelacion'],
        CORTES_B if es_grupo_b.loc[idx] else CORTES_A,
        ETIQUETAS_B if es_grupo_b.loc[idx] else ETIQUETAS_A
    )
    for idx, row in df.iterrows()
]

# ── Verificación ──────────────────────────────────────
print("Grupo A (programas y sedes regulares):")
print(df[~es_grupo_b]['Seguimiento'].value_counts().reindex(ETIQUETAS_A))

print("\nGrupo B (Modas + Minca + Buritaca):")
print(df[es_grupo_b]['Seguimiento'].value_counts().reindex(ETIQUETAS_B))

print(f"\nSin seguimiento asignado: {df['Seguimiento'].isna().sum()}")
# Out:
# Grupo A (programas y sedes regulares):
# Seguimiento
# Seguimiento 1    33
# Seguimiento 2     8
# Seguimiento 3    13
# Name: count, dtype: int64
#
# Grupo B (Modas + Minca + Buritaca):
# Seguimiento
# Seguimiento 1     5.0
# Seguimiento 2    13.0
# Seguimiento 3     NaN
# Name: count, dtype: float64
#
# Sin seguimiento asignado: 9

# %%
df.head(5)
# Out:
#   Nombre_periodo Nombre_nivel Fecha_cancelacion Nombre_causa_cancelacion  \
# 0         2026-1  Semestre 01        2026-03-09               Voluntario
# 1         2026-1  Semestre 01        2026-03-13             Aplazamiento
# 2         2026-1  Semestre 01        2026-03-31               Voluntario
# 3         2026-1  Semestre 01        2026-04-20               Voluntario
# 4         2026-1  Semestre 01        2026-05-11               Voluntario
#
#                              Observacion_cancelacion  Edad Genero      Sede  \
# 0  El estudiante se realiza retiro voluntario de ...    20      M  BASTIDAS
# 1  El estudiante aplaza su semestre por motivos p...    18      M  BASTIDAS
# 2  El estudiante decide retirarse por dificultade...    23      M  BASTIDAS
# 3  La estudiante se retira del programa  por moti...    25      F  BASTIDAS
# 4  La estudiante se retira del programa por temas...    32      F  BASTIDAS
#
#                             Nombre_programa_limpio  \
# 0  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 1  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 2  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 3  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 4  TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
#
#                  Causa_definitiva Genero_label    Seguimiento
# 0              Motivos personales    Masculino  Seguimiento 1
# 1                    Aplazamiento    Masculino  Seguimiento 1
# 2  Razones laborales o económicas    Masculino  Seguimiento 1
# 3        Responsabilidad familiar     Femenino  Seguimiento 2
# 4  Razones laborales o económicas     Femenino  Seguimiento 2

# %%
TODAS_ETIQUETAS = ['Seguimiento 1', 'Seguimiento 2', 'Seguimiento 3']

df['Seguimiento_corto'] = df['Seguimiento'].str.replace(r'\s*\(.*\)', '', regex=True)

fig, ax = plt.subplots(figsize=(8, 4))

seg_counts = df['Seguimiento_corto'].value_counts().reindex(TODAS_ETIQUETAS).fillna(0)
seg_tasa = (seg_counts / TOTAL_EST * 100).round(1)

bars = ax.bar(seg_tasa.index, seg_tasa.values,
              color=[AZUL, VERDE_AGUA, MAGENTA], edgecolor='white', width=0.55)

for bar, tasa, cant in zip(bars, seg_tasa.values, seg_counts.values):
    ax.text(bar.get_x() + bar.get_width()/2, tasa + 0.2,
            f'{tasa}%\n({int(cant)} cancel.)', ha='center', fontsize=9, color=OSCURO)

ax.axhline(TASA_GLOBAL, color='gray', linewidth=1, linestyle=':', label=f'Tasa global {TASA_GLOBAL}%')
ax.legend(fontsize=8)
ax.set_title('Cancelaciones por Seguimiento — Tasa sobre Estudiantes', fontweight='bold', pad=12)
ax.set_ylabel('Tasa de cancelación (%)')
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
tabla_seg = df.groupby('Seguimiento_corto', observed=True).size().reset_index(name='Cancelaciones')
tabla_seg['% del total estud.'] = (tabla_seg['Cancelaciones'] / TOTAL_EST * 100).round(2).astype(str) + '%'
tabla_seg['% de cancelados'] = (tabla_seg['Cancelaciones'] / TOTAL_CANCEL * 100).round(1).astype(str) + '%'
display(tabla_seg)
# Out:
#   Seguimiento_corto  Cancelaciones % del total estud. % de cancelados
# 0     Seguimiento 1             38              4.31%           46.9%
# 1     Seguimiento 2             21              2.38%           25.9%
# 2     Seguimiento 3             13              1.48%           16.0%

# %%
top4 = df['Nombre_programa_limpio'].value_counts().head(4).index
df_top = df[df['Nombre_programa_limpio'].isin(top4)]

# Totales de estudiantes por programa
est_prog = df_est.groupby('Nombre_programa_limpio')['Numero_identificacion'].nunique()

evol_prog = df_top.groupby(['Seguimiento_corto', 'Nombre_programa_limpio']).size().reset_index(name='Cancelaciones')
evol_prog['Total_est'] = evol_prog['Nombre_programa_limpio'].map(est_prog)
evol_prog['Tasa'] = (evol_prog['Cancelaciones'] / evol_prog['Total_est'] * 100).round(1)

fig, ax = plt.subplots(figsize=(10, 4))

for i, prog in enumerate(top4):
    data = evol_prog[evol_prog['Nombre_programa_limpio'] == prog].set_index('Seguimiento_corto').reindex(TODAS_ETIQUETAS).fillna(0)
    ax.plot(data.index, data['Tasa'], marker='o', label=prog, color=USM_TODOS[i])

ax.set_title('Tasa de Cancelación por Seguimiento y Programa (%)', fontweight='bold', pad=12)
ax.set_ylabel('Tasa (%)')
ax.legend(fontsize=7, loc='best')
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
evol_prog = df.groupby(['Seguimiento_corto', 'Nombre_programa_limpio'], observed=True).size().reset_index(name='Cancelaciones')
est_prog = df_est.groupby('Nombre_programa_limpio')['Numero_identificacion'].nunique()
evol_prog['Total_est'] = evol_prog['Nombre_programa_limpio'].map(est_prog)
evol_prog['Tasa'] = (evol_prog['Cancelaciones'] / evol_prog['Total_est'] * 100).round(2).astype(str) + '%'
display(evol_prog.sort_values(['Seguimiento_corto', 'Nombre_programa_limpio']).reset_index(drop=True))
# Out:
#    Seguimiento_corto                             Nombre_programa_limpio  \
# 0      Seguimiento 1    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 1      Seguimiento 1       TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS
# 2      Seguimiento 1   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS
# 3      Seguimiento 1  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...
# 4      Seguimiento 1                    TECNOLOGÍA EN MARKETING DIGITAL
# 5      Seguimiento 2    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 6      Seguimiento 2       TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS
# 7      Seguimiento 2  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...
# 8      Seguimiento 2                    TECNOLOGÍA EN MARKETING DIGITAL
# 9      Seguimiento 3   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS
# 10     Seguimiento 3  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...
#
#     Cancelaciones  Total_est    Tasa
# 0              12        210   5.71%
# 1               4         76   5.26%
# 2               7        153   4.58%
# 3               7        176   3.98%
# 4               8        267    3.0%
# 5               2        210   0.95%
# 6               9         76  11.84%
# 7               6        176   3.41%
# 8               4        267    1.5%
# 9               2        153   1.31%
# 10             11        176   6.25%

# %%
evol_causa = df.groupby(['Seguimiento_corto', 'Causa_definitiva'], observed=True).size().reset_index(name='Cancelaciones')
evol_causa['Tasa'] = (evol_causa['Cancelaciones'] / TOTAL_EST * 100).round(2)

pivot_causa = evol_causa.pivot(index='Seguimiento_corto', columns='Causa_definitiva', values='Tasa').reindex(TODAS_ETIQUETAS).fillna(0)

fig, ax = plt.subplots(figsize=(10, 4))

for col in pivot_causa.columns:
    ax.plot(pivot_causa.index, pivot_causa[col], marker='o', label=col)

ax.set_title('Tasa de Cancelación por Seguimiento y Causa (%)', fontweight='bold', pad=12)
ax.set_ylabel('Tasa (%)')
ax.legend(fontsize=7, loc='best')
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.show()

# Tabla resumen
evol_causa = df.groupby(['Seguimiento_corto', 'Causa_definitiva'], observed=True).size().reset_index(name='Cancelaciones')
evol_causa['Tasa'] = (evol_causa['Cancelaciones'] / TOTAL_EST * 100).round(3).astype(str) + '%'
display(evol_causa.sort_values(['Seguimiento_corto', 'Causa_definitiva']).reset_index(drop=True))
# Out:
#    Seguimiento_corto                       Causa_definitiva  Cancelaciones  \
# 0      Seguimiento 1                           Aplazamiento              3
# 1      Seguimiento 1                       Cambio de ciudad              3
# 2      Seguimiento 1       Cambio de institución o programa              4
# 3      Seguimiento 1  Deserción por desinterés o requisitos              1
# 4      Seguimiento 1                     Motivos personales              6
# 5      Seguimiento 1         Razones laborales o económicas             15
# 6      Seguimiento 1               Responsabilidad familiar              3
# 7      Seguimiento 1                                  Salud              3
# 8      Seguimiento 2                       Cambio de ciudad              1
# 9      Seguimiento 2       Cambio de institución o programa              4
# 10     Seguimiento 2             Cancelación administrativa              8
# 11     Seguimiento 2  Deserción por desinterés o requisitos              1
# 12     Seguimiento 2                     Motivos personales              3
# 13     Seguimiento 2         Razones laborales o económicas              2
# 14     Seguimiento 2               Responsabilidad familiar              2
# 15     Seguimiento 3             Cancelación administrativa             13
#
#       Tasa
# 0   0.341%
# 1   0.341%
# 2   0.454%
# 3   0.114%
# 4   0.681%
# 5   1.703%
# 6   0.341%
# 7   0.341%
# 8   0.114%
# 9   0.454%
# 10  0.908%
# 11  0.114%
# 12  0.341%
# 13  0.227%
# 14  0.227%
# 15  1.476%

# %%
tabla_seg = df.groupby('Seguimiento_corto', observed=True).size().reset_index(name='Cancelaciones')
tabla_seg['Seguimiento_corto'] = pd.Categorical(tabla_seg['Seguimiento_corto'], categories=TODAS_ETIQUETAS, ordered=True)
tabla_seg = tabla_seg.sort_values('Seguimiento_corto').reset_index(drop=True)
tabla_seg['% del total estud.'] = (tabla_seg['Cancelaciones'] / TOTAL_EST * 100).round(1).astype(str) + '%'
tabla_seg['% de cancelados'] = (tabla_seg['Cancelaciones'] / TOTAL_CANCEL * 100).round(1).astype(str) + '%'
tabla_seg
# Out:
#   Seguimiento_corto  Cancelaciones % del total estud. % de cancelados
# 0     Seguimiento 1             38               4.3%           46.9%
# 1     Seguimiento 2             21               2.4%           25.9%
# 2     Seguimiento 3             13               1.5%           16.0%

# %%
fig, ax = plt.subplots(figsize=(10, 4))

est_por_sem = df_est.groupby('Nombre_nivel')['Numero_identificacion'].nunique().reset_index(name='Total_est')
cancel_por_sem = df.groupby('Nombre_nivel').size().reset_index(name='Cancelaciones')
merged = cancel_por_sem.merge(est_por_sem, on='Nombre_nivel', how='left')
merged['Tasa'] = (merged['Cancelaciones'] / merged['Total_est'] * 100).round(1)
merged = merged.sort_values('Nombre_nivel')

bars = ax.bar(merged['Nombre_nivel'], merged['Tasa'],
              color=AZUL, edgecolor='white', width=0.6)

for bar, tasa, cancel, total in zip(bars, merged['Tasa'], merged['Cancelaciones'], merged['Total_est']):
    ax.text(bar.get_x() + bar.get_width()/2, tasa + 0.3,
            f'{tasa}%\n({cancel}/{total})', ha='center', fontsize=9, color=OSCURO)

ax.axhline(TASA_GLOBAL, color=MAGENTA, linewidth=1.5, linestyle='--', label=f'Tasa global {TASA_GLOBAL}%')
ax.legend(fontsize=9)
ax.set_title('Cancelaciones por Semestre — Tasa vs Estudiantes Matriculados', fontweight='bold', pad=12)
ax.set_ylabel('Tasa de cancelación (%)')
ax.tick_params(axis='x', rotation=30)
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

merged
# Out:
#   Nombre_nivel  Cancelaciones  Total_est  Tasa
# 0  Semestre 01             62        647   9.6
# 1  Semestre 02             19        234   8.1

# %%
# ── Semestre × Programa ───────────────────────────────
orden_sem = sorted(df['Nombre_nivel'].unique())

pivot_sem = df.groupby(
    ['Nombre_nivel', 'Nombre_programa_limpio']
).size().unstack(fill_value=0).reindex(orden_sem)

fig, ax = plt.subplots(figsize=(13, 5))
pivot_sem.plot(kind='bar', ax=ax,
               color=USM_TODOS[:pivot_sem.shape[1]],
               edgecolor='white', width=0.75)

ax.set_title('Cancelaciones por Semestre y Programa', fontweight='bold', pad=12)
ax.set_xlabel('Semestre')
ax.set_ylabel('Cancelaciones')
ax.tick_params(axis='x', rotation=30)
ax.legend(title='Programa', fontsize=7, bbox_to_anchor=(1, 1))
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

pivot_sem 

# Tabla resumen
orden_sem = sorted(df['Nombre_nivel'].unique())
pivot_sem_prog = df.groupby(['Nombre_nivel', 'Nombre_programa_limpio']).size().reset_index(name='Cancelaciones')
est_sem_prog = df_est.groupby(['Nombre_nivel', 'Nombre_programa_limpio'])['Numero_identificacion'].nunique().reset_index(name='Total_est')
pivot_sem_prog = pivot_sem_prog.merge(est_sem_prog, on=['Nombre_nivel', 'Nombre_programa_limpio'], how='right').fillna(0)
pivot_sem_prog['Tasa'] = (pivot_sem_prog['Cancelaciones'] / pivot_sem_prog['Total_est'] * 100).round(1).astype(str) + '%'
display(pivot_sem_prog.sort_values(['Nombre_nivel', 'Nombre_programa_limpio']).reset_index(drop=True))
# Out:
#   Nombre_nivel                             Nombre_programa_limpio  \
# 0  Semestre 01    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 1  Semestre 01       TECNOLOGÍA EN GESTIÓN DE PRODUCCIÓN DE MODAS
# 2  Semestre 01   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS
# 3  Semestre 01  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...
# 4  Semestre 01                    TECNOLOGÍA EN MARKETING DIGITAL
# 5  Semestre 02    TECNOLOGÍA EN GESTIÓN DE OPERACIONES LOGÍSTICAS
# 6  Semestre 02   TECNOLOGÍA EN GESTIÓN DE SERVICIOS GASTRONÓMICOS
# 7  Semestre 02  TECNOLOGÍA EN GESTIÓN DEL TURISMO CULTURAL Y D...
# 8  Semestre 02                    TECNOLOGÍA EN MARKETING DIGITAL
#
#    Cancelaciones  Total_est   Tasa
# 0             13        177   7.3%
# 1             13         76  17.1%
# 2              8        116   6.9%
# 3             18         90  20.0%
# 4             10        189   5.3%
# 5              2         33   6.1%
# 6              1         37   2.7%
# 7              9         86  10.5%
# 8              7         78   9.0%

# %%
# ── Semestre × Causa ──────────────────────────────────
pivot_causa_sem = df.groupby(
    ['Nombre_nivel', 'Causa_definitiva']
).size().unstack(fill_value=0).reindex(orden_sem)

fig, ax = plt.subplots(figsize=(11, 5))
pivot_causa_sem.plot(kind='bar', ax=ax,
                     color=USM_TODOS[:pivot_causa_sem.shape[1]],
                     edgecolor='white', width=0.75)

ax.set_title('Cancelaciones por Semestre y Causa', fontweight='bold', pad=12)
ax.set_xlabel('Semestre')
ax.set_ylabel('Cancelaciones')
ax.tick_params(axis='x', rotation=30)
ax.legend(title='Causa', fontsize=7, bbox_to_anchor=(1, 1))
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

pivot_causa_sem

# Tabla resumen
pivot_causa_sem = df.groupby(['Nombre_nivel', 'Causa_definitiva']).size().reset_index(name='Cancelaciones')
pivot_causa_sem['Tasa'] = (pivot_causa_sem['Cancelaciones'] / TOTAL_EST * 100).round(2).astype(str) + '%'
display(pivot_causa_sem.sort_values(['Nombre_nivel', 'Causa_definitiva']).reset_index(drop=True))
# Out:
#    Nombre_nivel                       Causa_definitiva  Cancelaciones   Tasa
# 0   Semestre 01                           Aplazamiento              3  0.34%
# 1   Semestre 01                       Cambio de ciudad              4  0.45%
# 2   Semestre 01       Cambio de institución o programa              8  0.91%
# 3   Semestre 01             Cancelación administrativa             17  1.93%
# 4   Semestre 01  Deserción por desinterés o requisitos              2  0.23%
# 5   Semestre 01                     Motivos personales              7  0.79%
# 6   Semestre 01         Razones laborales o económicas             13  1.48%
# 7   Semestre 01               Responsabilidad familiar              5  0.57%
# 8   Semestre 01                                  Salud              3  0.34%
# 9   Semestre 02                           Aplazamiento              1  0.11%
# 10  Semestre 02                       Cambio de ciudad              1  0.11%
# 11  Semestre 02             Cancelación administrativa              4  0.45%
# 12  Semestre 02                     Motivos personales              2  0.23%
# 13  Semestre 02         Razones laborales o económicas             10  1.14%
# 14  Semestre 02                                  Salud              1  0.11%

# %%
tabla_sem = df.groupby('Nombre_nivel').size().reset_index(name='Cancelaciones').sort_values('Nombre_nivel')
# Merge con totales de estudiantes
est_sem = df_est.groupby('Nombre_nivel')['Numero_identificacion'].nunique().reset_index(name='Total_estudiantes')
tabla_sem = tabla_sem.merge(est_sem, on='Nombre_nivel', how='left')
tabla_sem['Tasa'] = (tabla_sem['Cancelaciones'] / tabla_sem['Total_estudiantes'] * 100).round(1).astype(str) + '%'
tabla_sem = tabla_sem.rename(columns={'Nombre_nivel': 'Semestre'}).reset_index(drop=True)
tabla_sem
# Out:
#       Semestre  Cancelaciones  Total_estudiantes  Tasa
# 0  Semestre 01             62                647  9.6%
# 1  Semestre 02             19                234  8.1%
